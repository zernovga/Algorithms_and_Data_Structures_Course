# %% [markdown]
# # Задача 1

# %% [markdown]
# Имеется указатель на начало списка и необходимо найти середину связного списка (в общем случае — произвольный элемент номер n).

# %% [markdown]
# # Задача 2

# %% [markdown]
# Даны 3 стека `A, B, C`. Стек `A` содержит `n` уникальных чисел в порядке убывания (на вершине стека наименьшее число). Необходимо перенести все числа в стек `C` сохранив их порядок.

# %% [markdown]
# # Задача 3

# %% [markdown]
# Рисунок задан в виде матрицы `A`, в которой элемент `A[y][x]` определяет цвет пикселя на пересечении строки `y` и столбца `x`. Перекрасить в цвет `c` одноцветную область, начиная с пикселя `(x0,y0)`.
#
# ![image.png](attachment:image.png)

# %%
# Out:
# [[0, 2, 0, 1, 1],
#  [2, 2, 2, 2, 2],
#  [0, 2, 0, 2, 2],
#  [3, 3, 1, 2, 2],
#  [0, 1, 1, 0, 0]]

# %% [markdown]
# # Задача 4

# %% [markdown]
# Дан массив из $N$ положительных целых чисел. Вывести $k$ наибольших элемента из массива
#
# **Пример 1**:
#
# **Ввод:**
# ```py
# N = 5, k = 2
# arr[] = {12,5,787,1,23}
# ```
# **Вывод:** `787 23`
#
# **Пример 2**:
#
# **Ввод**:
# ```py
# N = 7, k = 3
# arr[] = {1,23,12,9,30,2,50}
# ```
# Вывод: `50 30 23`
#
# **Задание:**
#
# Завершите функцию `kLargest()`, принимающую массив `arr`, `N` and `K` в качестве параметров и возвращающую список из $k$ наибольших элементов в порядке убывания.

# %%
def kLargest(arr, n, k):
    ...
